# %%
import gymnasium as gym
import highway_env

import torch
import torch.nn as nn
import gpytorch as gpt
import numpy as np
from collections import namedtuple
from tqdm import tqdm_notebook as tqdm
from tqdm import trange

from arch.scripts.record_utils import *

# %%
from highway_env.envs.roundabout_env import RoundaboutEnv
from highway_env.vehicle.controller import MDPVehicle

class ContinuousRoundaboutEnv(RoundaboutEnv):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        super().configure({
            "action": {
                "type": "ContinuousAction",
            },
            "observation": {
                "type": "Kinematics"
            }
        })

    def _rewards(self, action: np.ndarray) -> float:
        # we remove the lane_change_reward, which was `action in [0, 2]`

        return {
            "collision_reward": self.vehicle.crashed,
            "high_speed_reward": MDPVehicle.get_speed_index(self.vehicle)
            / (MDPVehicle.DEFAULT_TARGET_SPEEDS.size - 1),
            "on_road_reward": self.vehicle.on_road,
        }

# %%
env = ContinuousRoundaboutEnv(render_mode='rgb_array')
env.reset()

env, display = record_videos(env)

env.reset()
done = False
truncated = False
while not done and not truncated:
    action = env.action_space.sample()
    obs, reward, done, truncated, info = env.step(action)
    print("reward: ", reward)
    print("done: ", done)
    print("truncated: ", truncated)
    print("info: ", info)
display.stop()
del display
env.close()
show_videos()
# Out:
# [12/Dec/2023 21:53:04] INFO - Successfully started X with display ":1307".
# /Users/neha/anaconda3/envs/rl/lib/python3.10/site-packages/gymnasium/wrappers/record_video.py:94: UserWarning: WARN: Overwriting existing videos at /Users/neha/Documents/College/f23/CS378/videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# reward:  0.0
# done:  False
# truncated:  False
# info:  {'speed': 10.421455085277548, 'crashed': False, 'action': array([ 0.48429102, -0.88316995], dtype=float32), 'rewards': {'collision_reward': False, 'high_speed_reward': 0.0, 'on_road_reward': False}}
# reward:  0.0
# done:  False
# truncated:  False
# info:  {'speed': 11.866518139839155, 'crashed': False, 'action': array([0.2890126, 0.6204504], dtype=float32), 'rewards': {'collision_reward': False, 'high_speed_reward': 0.0, 'on_road_reward': False}}
# reward:  0.0
# done:  False
# truncated:  False
# info:  {'speed': 8.615130066871625, 'crashed': False, 'action': array([-0.6502776, -0.6716103], dtype=float32), 'rewards': {'collision_reward': False, 'high_speed_reward': 0.0, 'on_road_reward': False}}
# reward:  0.0
# done:  False
# truncated:  False
# info:  {'speed': 10.947243899106953, 'crashed': False, 'action': array([0.46642277, 0.9964922 ], dtype=float32), 'rewards': {'collision_reward': False, 'high_speed_reward': 0.0, 'on_road_reward': False}}
# reward:  0.8333333333333334
# done:  False
# truncated:  False
# info:  {'speed': 10.962943534366751, 'crashed': False, 'action': array([0.00313993, 0.31395498], dtype=float32), 'rewards': {'collision_reward': False, 'high_speed_reward': 0.0, 'on_road_reward': True}}
# reward:  0.0
# done:  False
# truncated:  False
# info:  {'speed': 14.668680827133322, 'crashed': False, 'action': array([ 0.74114746, -0.71302176], dtype=float32), 'rewards': {'collision_reward': False, 'high_speed_reward': 0.0, 'on_road_reward': False}}
# Moviepy - Building video /Users/neha/Documents/College/f23/CS378/videos/rl-video-episode-0.mp4.
# Moviepy - Writing video /Users/neha/Documents/College/f23/CS378/videos/rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /Users/neha/Documents/College/f23/CS378/videos/rl-video-episode-0.mp4
# reward:  0.0
# done:  True
# truncated:  False
# info:  {'speed': 5.715337835031261, 'crashed': True, 'action': array([-0.9819391 ,  0.26202238], dtype=float32), 'rewards': {'collision_reward': True, 'high_speed_reward': 0.0, 'on_road_reward': True}}
# <video alt="videos/rl-video-episode-0.mp4" autoplay
#                       loop controls style="height: 400px;">
#                       <source src="data:video/mp4;base64,..." type="video/mp4" />
#                  </video>

# %%
class RandomNormalNoisyObservation(gym.ObservationWrapper):
    """Adds random Normal noise to the observations of the environment."""

    def __init__(self, env, loc=0.0, scale=0.00005):
        """Initializes the :class:`RandomNormalNoisyObservation` wrapper.

        Args:
            env (gym.Env): The environment to apply the wrapper
            loc (float, optional): Mean ("centre") of the noise distribution.
                Defaults to 0.0.
            scale (float, optional): Standard deviation (spread or "width") of the noise distribution.
                Must be non-negative. Defaults to 0.0001.
        """
        super().__init__(env)
        self.loc = loc
        self.scale = scale

    def observation(self, observation):
        """Returns the potentially modified observation."""
        return observation + np.random.normal(loc=self.loc, scale=self.scale, size=observation.shape)

# %%
# !git clone --depth=1 --branch=master https://github.com/liuzuxin/safe-mbrl.git safembrl
# !rm -rf safembrl/.git
# !touch safembrl/__init__.py

# %%
mpc_config = {
    'optimizer': 'CEM',
    'horizon': 8,
    'gamma': 0.98,
    'RANDOM': {
        'popsize': 5000,
    },
    'CEM': {
        'popsize': 500,
        'max_iters': 5,
        'num_elites': 10,
        'epsilon': 0.01,
        'alpha': 0.1,
        'init_mean': 0,
        'init_var': 1,
    },

}

cost_config = {
    'model_param': {
        'boosting_type': 'gbdt',
        'learning_rate': 0.3,
        'max_depth': 8,
        'n_estimators': 400,
        'n_jobs': 1,
        'num_leaves': 12,
    },
    'max_ratio': 3,
    'unsafe_buffer_size': 10000,
    'safe_buffer_size': 50000,
    'batch': 2000,
    'save': False,
    'save_folder': None,
    'load': False,
    'load_folder': None,
    'state_size': 25,
    'action_size': 2,
}

dynamic_config = {
    'n_ensembles': 5,
    'data_split': 0.8,
    'n_epochs': 70,
    'activation': 'relu',
    'batch_size': 256,
    'buffer_size': 500000,
    'hidden_sizes': [1024, 1024, 1024],
    'learning_rate': 0.001,
    'test_freq': 5,
    'test_ratio': 0.15,
    'load': False,
    'load_folder': None,
    'save': False,
    'save_folder': None,
}

env = ContinuousRoundaboutEnv()
env = RandomNormalNoisyObservation(env)
env.reset()

from safembrl.mbrl import SafeMPC, RegressionModelEnsemble, CostModel

STATE_DIM = 25
ACTION_DIM = 2

dynamic_model = RegressionModelEnsemble(STATE_DIM+ACTION_DIM, STATE_DIM, config=dynamic_config)
cost_model = CostModel(env, config=cost_config)
mpc_controller = SafeMPC(env, mpc_config, cost_model=cost_model, n_ensembles=dynamic_config['n_ensembles'])

# %%
Transition = namedtuple('Transition', ['state', 'action', 'next_state', 'safe_next_state', 'rewards'])

def collect_interaction_data(env, cost_model, dynamics_model, size=1000):
    done = True
    truncated = False
    for i in trange(size, desc="Collecting interaction data"):
        if done or truncated:
            previous_obs, info = env.reset()

        action = env.action_space.sample()
        obs, reward, done, truncated, info = env.step(action)
        safe_next_state = 1 if info['rewards']['on_road_reward'] and not info['rewards']['collision_reward'] else 0
        data = Transition(torch.Tensor(previous_obs),
                                torch.Tensor(action),
                                torch.Tensor(obs),
                                torch.Tensor([safe_next_state]),
                                torch.Tensor([reward]))
        previous_obs = obs

        cost_model.add_data_point(data.next_state, 1 if data.safe_next_state == 0 else 0)
        x, y = np.concatenate((data.state.flatten(), data.action)), data.next_state.flatten()
        dynamics_model.add_data_point(x, y)
        
    return data

env = ContinuousRoundaboutEnv(render_mode='rgb_array')
env = RandomNormalNoisyObservation(env)
env.reset()
collect_interaction_data(env, cost_model, dynamic_model)
# Out:
# Collecting interaction data: 100%|██████████| 1000/1000 [00:17<00:00, 56.56it/s]
# Transition(state=tensor([[ 1.0001e+00, -1.5704e-01,  9.9999e-01, -1.0621e-01,  8.3245e-02],
#         [ 1.0000e+00,  1.4651e-01,  6.0666e-02,  1.1076e-01,  9.8168e-02],
#         [-5.5372e-06, -1.6659e-06,  1.0253e-04,  7.5835e-05,  3.3696e-05],
#         [ 7.8970e-05, -5.7181e-05,  3.6129e-05, -2.2790e-05,  2.9797e-05],
#         [ 3.1186e-05,  2.4308e-06, -4.4669e-05, -6.8315e-05,  4.0842e-05]]), action=tensor([-0.2454, -0.7050]), next_state=tensor([[ 1.0001e+00, -1.5906e-01,  9.9988e-01,  3.5605e-02,  1.1422e-01],
#         [ 1.0000e+00,  1.4902e-01,  1.0000e+00, -3.5159e-02,  7.0790e-02],
#         [-4.1030e-05, -8.0414e-05,  4.9228e-06, -2.8079e-05, -1.6980e-05],
#         [-7.0110e-06, -6.1815e-05,  2.0318e-05, -4.9781e-05,  7.3847e-05],
#         [ 3.0159e-05, -3.0420e-06, -2.8419e-05,  5.9205e-06, -9.7853e-06]]), safe_next_state=tensor([0.]), rewards=tensor([0.]))

# %%
dynamic_model.reset_model()
dynamic_model.fit(use_data_buf=True, normalize=True)
cost_model.fit()
# Out:
# return data util  1000
# [4/70],loss train m: 0.6256, v: 0.0001, test m: 0.7306, v: 0.0000
# [9/70],loss train m: 0.5146, v: 0.0000, test m: 0.6841, v: 0.0000
# [14/70],loss train m: 0.4374, v: 0.0001, test m: 0.6781, v: 0.0000
# [19/70],loss train m: 0.3819, v: 0.0000, test m: 0.6689, v: 0.0001
# [24/70],loss train m: 0.3360, v: 0.0000, test m: 0.6575, v: 0.0000
# [29/70],loss train m: 0.2932, v: 0.0000, test m: 0.6611, v: 0.0001
# [34/70],loss train m: 0.2553, v: 0.0001, test m: 0.6551, v: 0.0001
# [39/70],loss train m: 0.2267, v: 0.0001, test m: 0.6594, v: 0.0002
# [44/70],loss train m: 0.2005, v: 0.0001, test m: 0.6655, v: 0.0001
# [49/70],loss train m: 0.1815, v: 0.0000, test m: 0.6699, v: 0.0008
# [54/70],loss train m: 0.1566, v: 0.0000, test m: 0.6736, v: 0.0006
# [59/70],loss train m: 0.1388, v: 0.0000, test m: 0.6729, v: 0.0002
# [64/70],loss train m: 0.1243, v: 0.0000, test m: 0.6752, v: 0.0002
# [LightGBM] [Info] Number of positive: 773, number of negative: 227
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000122 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6375
# [LightGBM] [Info] Number of data points in the train set: 1000, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.773000 -> initscore=1.225329
# [LightGBM] [Info] Start training from score 1.225329
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# unsafe data accuracy: 100.00%, safe data accuracy: 100.00%

# %%
import time
from safembrl.utils.logx import EpochLogger
from safembrl.utils.run_utils import setup_logger_kwargs, combined_shape, load_config, seed_torch

logger_kwargs = setup_logger_kwargs('safembrl', 24, './logs')
logger = EpochLogger(**logger_kwargs)

env = ContinuousRoundaboutEnv()
env = RandomNormalNoisyObservation(env)
env.reset()

start_time = time.time()
# Main loop: collect experience in env and update/log each epoch
total_len = 0 # total interactions
total_epi = 0
for epoch in tqdm(range(5), desc='Epoch'): # update models per epoch
    for test_episode in tqdm(range(30), desc='Collecting episodes'): # collect data for episodes length
        obs, _, = env.reset()
        ep_ret, ep_cost, done = 0, 0, False
        obs = obs.flatten()
        mpc_controller.reset()
        done, truncated = False, False
        # with tqdm(total=11, desc='Collecting interactions') as pbar:
        while not done and not truncated:
            action = np.squeeze(np.array([mpc_controller.act(model=dynamic_model, state=obs)]))
            obs_next, reward, done, truncated, info = env.step(action)
            # print("reward: ", reward)
            # print("done: ", done)
            # print("truncated: ", truncated)
            # print("info: ", info)
            total_len += 1
            ep_ret += reward
            if not truncated and not done:
                x = np.concatenate((obs.flatten(), action))
                y = obs_next.flatten() #- obs
                dynamic_model.add_data_point(x, y)
                cost = 1 if reward == 0 else 0
                ep_cost += cost
                cost_model.add_data_point(obs_next, cost)
            obs = obs_next
                # pbar.update(1)
        logger.store(Rewards=ep_ret, Cost=ep_cost)
        logger.log_tabular('Epoch', epoch)
        logger.log_tabular('Episode', total_epi)
        logger.log_tabular('Cost', average_only=True)
        logger.log_tabular('TotalEnvInteracts', total_len)
        logger.log_tabular('Time', time.time()-start_time)
        logger.dump_tabular()
        total_epi += 1
    # training the model
    dynamic_model.fit(use_data_buf=True, normalize=True)
    cost_model.fit()
env.close()
# Out:
# Warning: Log dir ./logs/safembrl/safembrl_s24 already exists! Storing info there anyway.
# Logging data to ./logs/safembrl/safembrl_s24/progress.txt
# /var/folders/cp/ch7_5s3518bc53s7b6mvp7540000gp/T/ipykernel_64744/3698005483.py:16: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for epoch in tqdm(range(5), desc='Epoch'): # update models per epoch
# Epoch:   0%|          | 0/5 [00:00<?, ?it/s]
# /var/folders/cp/ch7_5s3518bc53s7b6mvp7540000gp/T/ipykernel_64744/3698005483.py:17: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for test_episode in tqdm(range(30), desc='Collecting episodes'): # collect data for episodes length
# Collecting episodes:   0%|          | 0/30 [00:00<?, ?it/s]
# ---------------------------------------
# |             Epoch |               0 |
# |           Episode |               0 |
# |              Cost |               5 |
# | TotalEnvInteracts |              11 |
# |              Time |            11.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               0 |
# |           Episode |               1 |
# |              Cost |               5 |
# | TotalEnvInteracts |              22 |
# |              Time |            22.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               0 |
# |           Episode |               2 |
# |              Cost |               7 |
# | TotalEnvInteracts |              33 |
# |              Time |            33.8 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               0 |
# |           Episode |               3 |
# |              Cost |               2 |
# | TotalEnvInteracts |              44 |
# |              Time |            45.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               0 |
# |           Episode |               4 |
# |              Cost |               3 |
# | TotalEnvInteracts |              55 |
# |              Time |            56.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               0 |
# |           Episode |               5 |
# |              Cost |               7 |
# | TotalEnvInteracts |              66 |
# |              Time |            68.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               0 |
# |           Episode |               6 |
# |              Cost |               5 |
# | TotalEnvInteracts |              77 |
# |              Time |              80 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               0 |
# |           Episode |               7 |
# |              Cost |               1 |
# | TotalEnvInteracts |              81 |
# |              Time |            84.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               0 |
# |           Episode |               8 |
# |              Cost |               7 |
# | TotalEnvInteracts |              92 |
# |              Time |            96.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               0 |
# |           Episode |               9 |
# |              Cost |               6 |
# | TotalEnvInteracts |             103 |
# |              Time |             108 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               0 |
# |           Episode |              10 |
# |              Cost |               3 |
# | TotalEnvInteracts |             114 |
# |              Time |             119 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               0 |
# |           Episode |              11 |
# |              Cost |               1 |
# | TotalEnvInteracts |             117 |
# |              Time |             122 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               0 |
# |           Episode |              12 |
# |              Cost |               5 |
# | TotalEnvInteracts |             124 |
# |              Time |             130 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               0 |
# |           Episode |              13 |
# |              Cost |               6 |
# | TotalEnvInteracts |             135 |
# |              Time |             141 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               0 |
# |           Episode |              14 |
# |              Cost |               0 |
# | TotalEnvInteracts |             137 |
# |              Time |             143 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               0 |
# |           Episode |              15 |
# |              Cost |               2 |
# | TotalEnvInteracts |             141 |
# |              Time |             148 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               0 |
# |           Episode |              16 |
# |              Cost |               6 |
# | TotalEnvInteracts |             152 |
# |              Time |             159 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               0 |
# |           Episode |              17 |
# |              Cost |               6 |
# | TotalEnvInteracts |             163 |
# |              Time |             170 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               0 |
# |           Episode |              18 |
# |              Cost |               1 |
# | TotalEnvInteracts |             174 |
# |              Time |             181 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               0 |
# |           Episode |              19 |
# |              Cost |               2 |
# | TotalEnvInteracts |             178 |
# |              Time |             185 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               0 |
# |           Episode |              20 |
# |              Cost |               3 |
# | TotalEnvInteracts |             189 |
# |              Time |             196 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               0 |
# |           Episode |              21 |
# |              Cost |               1 |
# | TotalEnvInteracts |             192 |
# |              Time |             199 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               0 |
# |           Episode |              22 |
# |              Cost |               0 |
# | TotalEnvInteracts |             194 |
# |              Time |             201 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               0 |
# |           Episode |              23 |
# |              Cost |               7 |
# | TotalEnvInteracts |             205 |
# |              Time |             213 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               0 |
# |           Episode |              24 |
# |              Cost |               1 |
# | TotalEnvInteracts |             208 |
# |              Time |             216 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               0 |
# |           Episode |              25 |
# |              Cost |               4 |
# | TotalEnvInteracts |             219 |
# |              Time |             227 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               0 |
# |           Episode |              26 |
# |              Cost |               4 |
# | TotalEnvInteracts |             230 |
# |              Time |             239 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               0 |
# |           Episode |              27 |
# |              Cost |               2 |
# | TotalEnvInteracts |             234 |
# |              Time |             243 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               0 |
# |           Episode |              28 |
# |              Cost |               0 |
# | TotalEnvInteracts |             236 |
# |              Time |             246 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               0 |
# |           Episode |              29 |
# |              Cost |               1 |
# | TotalEnvInteracts |             247 |
# |              Time |             256 |
# ---------------------------------------
# return data util  1231
# [4/70],loss train m: 0.2196, v: 0.0000, test m: 0.3277, v: 0.0002
# [9/70],loss train m: 0.1844, v: 0.0000, test m: 0.3343, v: 0.0001
# [14/70],loss train m: 0.1519, v: 0.0000, test m: 0.3352, v: 0.0002
# [19/70],loss train m: 0.1370, v: 0.0001, test m: 0.3422, v: 0.0001
# [24/70],loss train m: 0.1239, v: 0.0000, test m: 0.3484, v: 0.0002
# [29/70],loss train m: 0.1100, v: 0.0000, test m: 0.3526, v: 0.0002
# [34/70],loss train m: 0.0971, v: 0.0000, test m: 0.3558, v: 0.0003
# [LightGBM] [Info] Number of positive: 882, number of negative: 349
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000042 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 6375
# [LightGBM] [Info] Number of data points in the train set: 1231, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.716491 -> initscore=0.927120
# [LightGBM] [Info] Start training from score 0.927120
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# unsafe data accuracy: 100.00%, safe data accuracy: 100.00%
# /var/folders/cp/ch7_5s3518bc53s7b6mvp7540000gp/T/ipykernel_64744/3698005483.py:17: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for test_episode in tqdm(range(30), desc='Collecting episodes'): # collect data for episodes length
# Collecting episodes:   0%|          | 0/30 [00:00<?, ?it/s]
# ---------------------------------------
# |             Epoch |               1 |
# |           Episode |              30 |
# |              Cost |               5 |
# | TotalEnvInteracts |             258 |
# |              Time |             275 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               1 |
# |           Episode |              31 |
# |              Cost |               0 |
# | TotalEnvInteracts |             262 |
# |              Time |             280 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               1 |
# |           Episode |              32 |
# |              Cost |               2 |
# | TotalEnvInteracts |             273 |
# |              Time |             292 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               1 |
# |           Episode |              33 |
# |              Cost |               2 |
# | TotalEnvInteracts |             284 |
# |              Time |             303 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               1 |
# |           Episode |              34 |
# |              Cost |               1 |
# | TotalEnvInteracts |             295 |
# |              Time |             315 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               1 |
# |           Episode |              35 |
# |              Cost |               6 |
# | TotalEnvInteracts |             306 |
# |              Time |             327 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               1 |
# |           Episode |              36 |
# |              Cost |               0 |
# | TotalEnvInteracts |             317 |
# |              Time |             339 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               1 |
# |           Episode |              37 |
# |              Cost |               6 |
# | TotalEnvInteracts |             328 |
# |              Time |             350 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               1 |
# |           Episode |              38 |
# |              Cost |               3 |
# | TotalEnvInteracts |             339 |
# |              Time |             362 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               1 |
# |           Episode |              39 |
# |              Cost |               2 |
# | TotalEnvInteracts |             350 |
# |              Time |             374 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               1 |
# |           Episode |              40 |
# |              Cost |               0 |
# | TotalEnvInteracts |             361 |
# |              Time |             386 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               1 |
# |           Episode |              41 |
# |              Cost |               4 |
# | TotalEnvInteracts |             372 |
# |              Time |             398 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               1 |
# |           Episode |              42 |
# |              Cost |               1 |
# | TotalEnvInteracts |             383 |
# |              Time |             410 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               1 |
# |           Episode |              43 |
# |              Cost |               0 |
# | TotalEnvInteracts |             394 |
# |              Time |             422 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               1 |
# |           Episode |              44 |
# |              Cost |               2 |
# | TotalEnvInteracts |             405 |
# |              Time |             435 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               1 |
# |           Episode |              45 |
# |              Cost |               5 |
# | TotalEnvInteracts |             416 |
# |              Time |             447 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               1 |
# |           Episode |              46 |
# |              Cost |               2 |
# | TotalEnvInteracts |             427 |
# |              Time |             459 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               1 |
# |           Episode |              47 |
# |              Cost |               1 |
# | TotalEnvInteracts |             438 |
# |              Time |             471 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               1 |
# |           Episode |              48 |
# |              Cost |               0 |
# | TotalEnvInteracts |             449 |
# |              Time |             483 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               1 |
# |           Episode |              49 |
# |              Cost |               1 |
# | TotalEnvInteracts |             460 |
# |              Time |             495 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               1 |
# |           Episode |              50 |
# |              Cost |              10 |
# | TotalEnvInteracts |             471 |
# |              Time |             506 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               1 |
# |           Episode |              51 |
# |              Cost |               3 |
# | TotalEnvInteracts |             482 |
# |              Time |             518 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               1 |
# |           Episode |              52 |
# |              Cost |               4 |
# | TotalEnvInteracts |             493 |
# |              Time |             529 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               1 |
# |           Episode |              53 |
# |              Cost |               1 |
# | TotalEnvInteracts |             504 |
# |              Time |             541 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               1 |
# |           Episode |              54 |
# |              Cost |               1 |
# | TotalEnvInteracts |             507 |
# |              Time |             544 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               1 |
# |           Episode |              55 |
# |              Cost |               4 |
# | TotalEnvInteracts |             518 |
# |              Time |             557 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               1 |
# |           Episode |              56 |
# |              Cost |               2 |
# | TotalEnvInteracts |             529 |
# |              Time |             568 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               1 |
# |           Episode |              57 |
# |              Cost |               5 |
# | TotalEnvInteracts |             540 |
# |              Time |             580 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               1 |
# |           Episode |              58 |
# |              Cost |               0 |
# | TotalEnvInteracts |             551 |
# |              Time |             592 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               1 |
# |           Episode |              59 |
# |              Cost |               3 |
# | TotalEnvInteracts |             562 |
# |              Time |             604 |
# ---------------------------------------
# return data util  1516
# [4/70],loss train m: 0.2617, v: 0.0017, test m: 0.3681, v: 0.0008
# [9/70],loss train m: 0.2631, v: 0.0008, test m: 0.3928, v: 0.0007
# [14/70],loss train m: 0.2431, v: 0.0007, test m: 0.3982, v: 0.0008
# [19/70],loss train m: 0.2164, v: 0.0001, test m: 0.4004, v: 0.0006
# [24/70],loss train m: 0.2006, v: 0.0003, test m: 0.3990, v: 0.0005
# [29/70],loss train m: 0.1810, v: 0.0002, test m: 0.3866, v: 0.0002
# [34/70],loss train m: 0.1670, v: 0.0002, test m: 0.3957, v: 0.0003
# [LightGBM] [Info] Number of positive: 958, number of negative: 558
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000048 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 6375
# [LightGBM] [Info] Number of data points in the train set: 1516, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.631926 -> initscore=0.540489
# [LightGBM] [Info] Start training from score 0.540489
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# unsafe data accuracy: 100.00%, safe data accuracy: 100.00%
# /var/folders/cp/ch7_5s3518bc53s7b6mvp7540000gp/T/ipykernel_64744/3698005483.py:17: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for test_episode in tqdm(range(30), desc='Collecting episodes'): # collect data for episodes length
# Collecting episodes:   0%|          | 0/30 [00:00<?, ?it/s]
# ---------------------------------------
# |             Epoch |               2 |
# |           Episode |              60 |
# |              Cost |               4 |
# | TotalEnvInteracts |             573 |
# |              Time |             624 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |           Episode |              61 |
# |              Cost |               2 |
# | TotalEnvInteracts |             584 |
# |              Time |             636 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |           Episode |              62 |
# |              Cost |               5 |
# | TotalEnvInteracts |             595 |
# |              Time |             648 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |           Episode |              63 |
# |              Cost |               5 |
# | TotalEnvInteracts |             606 |
# |              Time |             659 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |           Episode |              64 |
# |              Cost |               6 |
# | TotalEnvInteracts |             617 |
# |              Time |             671 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |           Episode |              65 |
# |              Cost |               0 |
# | TotalEnvInteracts |             628 |
# |              Time |             683 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |           Episode |              66 |
# |              Cost |               3 |
# | TotalEnvInteracts |             639 |
# |              Time |             695 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |           Episode |              67 |
# |              Cost |               0 |
# | TotalEnvInteracts |             650 |
# |              Time |             707 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |           Episode |              68 |
# |              Cost |               9 |
# | TotalEnvInteracts |             661 |
# |              Time |             719 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |           Episode |              69 |
# |              Cost |               8 |
# | TotalEnvInteracts |             672 |
# |              Time |             731 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |           Episode |              70 |
# |              Cost |               0 |
# | TotalEnvInteracts |             682 |
# |              Time |             742 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |           Episode |              71 |
# |              Cost |               5 |
# | TotalEnvInteracts |             693 |
# |              Time |             755 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |           Episode |              72 |
# |              Cost |               0 |
# | TotalEnvInteracts |             704 |
# |              Time |             767 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |           Episode |              73 |
# |              Cost |               5 |
# | TotalEnvInteracts |             715 |
# |              Time |             779 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |           Episode |              74 |
# |              Cost |               0 |
# | TotalEnvInteracts |             726 |
# |              Time |             791 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |           Episode |              75 |
# |              Cost |               5 |
# | TotalEnvInteracts |             737 |
# |              Time |             802 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |           Episode |              76 |
# |              Cost |               4 |
# | TotalEnvInteracts |             748 |
# |              Time |             814 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |           Episode |              77 |
# |              Cost |               2 |
# | TotalEnvInteracts |             759 |
# |              Time |             825 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |           Episode |              78 |
# |              Cost |               7 |
# | TotalEnvInteracts |             770 |
# |              Time |             837 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |           Episode |              79 |
# |              Cost |               5 |
# | TotalEnvInteracts |             781 |
# |              Time |             848 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |           Episode |              80 |
# |              Cost |               3 |
# | TotalEnvInteracts |             792 |
# |              Time |             860 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |           Episode |              81 |
# |              Cost |               5 |
# | TotalEnvInteracts |             803 |
# |              Time |             872 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |           Episode |              82 |
# |              Cost |               0 |
# | TotalEnvInteracts |             814 |
# |              Time |             884 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |           Episode |              83 |
# |              Cost |               0 |
# | TotalEnvInteracts |             825 |
# |              Time |             896 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |           Episode |              84 |
# |              Cost |               2 |
# | TotalEnvInteracts |             836 |
# |              Time |             907 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |           Episode |              85 |
# |              Cost |               4 |
# | TotalEnvInteracts |             847 |
# |              Time |             919 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |           Episode |              86 |
# |              Cost |               8 |
# | TotalEnvInteracts |             858 |
# |              Time |             931 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |           Episode |              87 |
# |              Cost |               0 |
# | TotalEnvInteracts |             869 |
# |              Time |             943 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |           Episode |              88 |
# |              Cost |               4 |
# | TotalEnvInteracts |             880 |
# |              Time |             955 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |           Episode |              89 |
# |              Cost |               2 |
# | TotalEnvInteracts |             891 |
# |              Time |             966 |
# ---------------------------------------
# return data util  1815
# [4/70],loss train m: 0.1610, v: 0.0001, test m: 0.1853, v: 0.0001
# [9/70],loss train m: 0.1265, v: 0.0000, test m: 0.1812, v: 0.0001
# [14/70],loss train m: 0.1051, v: 0.0000, test m: 0.1835, v: 0.0000
# [19/70],loss train m: 0.0940, v: 0.0000, test m: 0.1849, v: 0.0000
# [24/70],loss train m: 0.0834, v: 0.0000, test m: 0.1881, v: 0.0000
# [29/70],loss train m: 0.0743, v: 0.0000, test m: 0.1912, v: 0.0000
# [34/70],loss train m: 0.0682, v: 0.0000, test m: 0.1932, v: 0.0000
# [39/70],loss train m: 0.0629, v: 0.0000, test m: 0.1952, v: 0.0000
# [LightGBM] [Info] Number of positive: 1061, number of negative: 754
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000055 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 6375
# [LightGBM] [Info] Number of data points in the train set: 1815, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.584573 -> initscore=0.341575
# [LightGBM] [Info] Start training from score 0.341575
# unsafe data accuracy: 100.00%, safe data accuracy: 100.00%
# /var/folders/cp/ch7_5s3518bc53s7b6mvp7540000gp/T/ipykernel_64744/3698005483.py:17: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for test_episode in tqdm(range(30), desc='Collecting episodes'): # collect data for episodes length
# Collecting episodes:   0%|          | 0/30 [00:00<?, ?it/s]
# ---------------------------------------
# |             Epoch |               3 |
# |           Episode |              90 |
# |              Cost |               1 |
# | TotalEnvInteracts |             902 |
# |              Time |             990 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |           Episode |              91 |
# |              Cost |               0 |
# | TotalEnvInteracts |             913 |
# |              Time |           1e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |           Episode |              92 |
# |              Cost |               3 |
# | TotalEnvInteracts |             924 |
# |              Time |        1.02e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |           Episode |              93 |
# |              Cost |               2 |
# | TotalEnvInteracts |             935 |
# |              Time |        1.03e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |           Episode |              94 |
# |              Cost |               1 |
# | TotalEnvInteracts |             946 |
# |              Time |        1.04e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |           Episode |              95 |
# |              Cost |               3 |
# | TotalEnvInteracts |             956 |
# |              Time |        1.05e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |           Episode |              96 |
# |              Cost |               0 |
# | TotalEnvInteracts |             967 |
# |              Time |        1.07e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |           Episode |              97 |
# |              Cost |               2 |
# | TotalEnvInteracts |             978 |
# |              Time |        1.08e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |           Episode |              98 |
# |              Cost |               2 |
# | TotalEnvInteracts |             989 |
# |              Time |        1.09e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |           Episode |              99 |
# |              Cost |               0 |
# | TotalEnvInteracts |           1e+03 |
# |              Time |        1.11e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |           Episode |             100 |
# |              Cost |               1 |
# | TotalEnvInteracts |        1.01e+03 |
# |              Time |        1.12e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |           Episode |             101 |
# |              Cost |               2 |
# | TotalEnvInteracts |        1.02e+03 |
# |              Time |        1.13e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |           Episode |             102 |
# |              Cost |               3 |
# | TotalEnvInteracts |        1.03e+03 |
# |              Time |        1.14e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |           Episode |             103 |
# |              Cost |               1 |
# | TotalEnvInteracts |        1.04e+03 |
# |              Time |        1.16e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |           Episode |             104 |
# |              Cost |               5 |
# | TotalEnvInteracts |        1.06e+03 |
# |              Time |        1.17e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |           Episode |             105 |
# |              Cost |               1 |
# | TotalEnvInteracts |        1.07e+03 |
# |              Time |        1.18e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |           Episode |             106 |
# |              Cost |               0 |
# | TotalEnvInteracts |        1.08e+03 |
# |              Time |        1.19e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |           Episode |             107 |
# |              Cost |               0 |
# | TotalEnvInteracts |        1.09e+03 |
# |              Time |        1.21e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |           Episode |             108 |
# |              Cost |               2 |
# | TotalEnvInteracts |         1.1e+03 |
# |              Time |        1.22e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |           Episode |             109 |
# |              Cost |               1 |
# | TotalEnvInteracts |        1.11e+03 |
# |              Time |        1.23e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |           Episode |             110 |
# |              Cost |               2 |
# | TotalEnvInteracts |        1.12e+03 |
# |              Time |        1.24e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |           Episode |             111 |
# |              Cost |               0 |
# | TotalEnvInteracts |        1.13e+03 |
# |              Time |        1.26e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |           Episode |             112 |
# |              Cost |               2 |
# | TotalEnvInteracts |        1.14e+03 |
# |              Time |        1.27e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |           Episode |             113 |
# |              Cost |               0 |
# | TotalEnvInteracts |        1.15e+03 |
# |              Time |        1.28e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |           Episode |             114 |
# |              Cost |               0 |
# | TotalEnvInteracts |        1.16e+03 |
# |              Time |        1.29e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |           Episode |             115 |
# |              Cost |               5 |
# | TotalEnvInteracts |        1.17e+03 |
# |              Time |         1.3e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |           Episode |             116 |
# |              Cost |               0 |
# | TotalEnvInteracts |        1.18e+03 |
# |              Time |        1.32e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |           Episode |             117 |
# |              Cost |               1 |
# | TotalEnvInteracts |         1.2e+03 |
# |              Time |        1.33e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |           Episode |             118 |
# |              Cost |               2 |
# | TotalEnvInteracts |        1.21e+03 |
# |              Time |        1.34e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |           Episode |             119 |
# |              Cost |               1 |
# | TotalEnvInteracts |        1.22e+03 |
# |              Time |        1.35e+03 |
# ---------------------------------------
# return data util  2112
# [4/70],loss train m: 0.0899, v: 0.0000, test m: 0.1102, v: 0.0000
# [9/70],loss train m: 0.0755, v: 0.0000, test m: 0.1151, v: 0.0000
# [14/70],loss train m: 0.0657, v: 0.0000, test m: 0.1208, v: 0.0000
# [19/70],loss train m: 0.0581, v: 0.0000, test m: 0.1234, v: 0.0000
# [24/70],loss train m: 0.0524, v: 0.0000, test m: 0.1252, v: 0.0000
# [29/70],loss train m: 0.0463, v: 0.0000, test m: 0.1280, v: 0.0000
# [34/70],loss train m: 0.0429, v: 0.0000, test m: 0.1306, v: 0.0000
# [LightGBM] [Info] Number of positive: 1104, number of negative: 1008
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000062 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 6375
# [LightGBM] [Info] Number of data points in the train set: 2112, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.522727 -> initscore=0.090972
# [LightGBM] [Info] Start training from score 0.090972
# unsafe data accuracy: 100.00%, safe data accuracy: 100.00%
# /var/folders/cp/ch7_5s3518bc53s7b6mvp7540000gp/T/ipykernel_64744/3698005483.py:17: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for test_episode in tqdm(range(30), desc='Collecting episodes'): # collect data for episodes length
# Collecting episodes:   0%|          | 0/30 [00:00<?, ?it/s]
# ---------------------------------------
# |             Epoch |               4 |
# |           Episode |             120 |
# |              Cost |               0 |
# | TotalEnvInteracts |        1.23e+03 |
# |              Time |        1.38e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |           Episode |             121 |
# |              Cost |               1 |
# | TotalEnvInteracts |        1.24e+03 |
# |              Time |        1.39e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |           Episode |             122 |
# |              Cost |               1 |
# | TotalEnvInteracts |        1.25e+03 |
# |              Time |        1.41e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |           Episode |             123 |
# |              Cost |               0 |
# | TotalEnvInteracts |        1.26e+03 |
# |              Time |        1.42e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |           Episode |             124 |
# |              Cost |               1 |
# | TotalEnvInteracts |        1.27e+03 |
# |              Time |        1.43e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |           Episode |             125 |
# |              Cost |               1 |
# | TotalEnvInteracts |        1.28e+03 |
# |              Time |        1.45e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |           Episode |             126 |
# |              Cost |               2 |
# | TotalEnvInteracts |         1.3e+03 |
# |              Time |        1.46e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |           Episode |             127 |
# |              Cost |               2 |
# | TotalEnvInteracts |        1.31e+03 |
# |              Time |        1.47e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |           Episode |             128 |
# |              Cost |               0 |
# | TotalEnvInteracts |        1.32e+03 |
# |              Time |        1.49e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |           Episode |             129 |
# |              Cost |               4 |
# | TotalEnvInteracts |        1.33e+03 |
# |              Time |         1.5e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |           Episode |             130 |
# |              Cost |               3 |
# | TotalEnvInteracts |        1.34e+03 |
# |              Time |        1.52e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |           Episode |             131 |
# |              Cost |               3 |
# | TotalEnvInteracts |        1.35e+03 |
# |              Time |        1.53e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |           Episode |             132 |
# |              Cost |               0 |
# | TotalEnvInteracts |        1.36e+03 |
# |              Time |        1.54e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |           Episode |             133 |
# |              Cost |               0 |
# | TotalEnvInteracts |        1.37e+03 |
# |              Time |        1.55e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |           Episode |             134 |
# |              Cost |               0 |
# | TotalEnvInteracts |        1.38e+03 |
# |              Time |        1.57e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |           Episode |             135 |
# |              Cost |               0 |
# | TotalEnvInteracts |        1.39e+03 |
# |              Time |        1.58e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |           Episode |             136 |
# |              Cost |               2 |
# | TotalEnvInteracts |         1.4e+03 |
# |              Time |        1.59e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |           Episode |             137 |
# |              Cost |               3 |
# | TotalEnvInteracts |        1.42e+03 |
# |              Time |        1.61e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |           Episode |             138 |
# |              Cost |               3 |
# | TotalEnvInteracts |        1.43e+03 |
# |              Time |        1.62e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |           Episode |             139 |
# |              Cost |               0 |
# | TotalEnvInteracts |        1.44e+03 |
# |              Time |        1.63e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |           Episode |             140 |
# |              Cost |               3 |
# | TotalEnvInteracts |        1.45e+03 |
# |              Time |        1.64e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |           Episode |             141 |
# |              Cost |               0 |
# | TotalEnvInteracts |        1.46e+03 |
# |              Time |        1.66e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |           Episode |             142 |
# |              Cost |               1 |
# | TotalEnvInteracts |        1.47e+03 |
# |              Time |        1.67e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |           Episode |             143 |
# |              Cost |               1 |
# | TotalEnvInteracts |        1.48e+03 |
# |              Time |        1.68e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |           Episode |             144 |
# |              Cost |               0 |
# | TotalEnvInteracts |        1.49e+03 |
# |              Time |         1.7e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |           Episode |             145 |
# |              Cost |               0 |
# | TotalEnvInteracts |         1.5e+03 |
# |              Time |        1.71e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |           Episode |             146 |
# |              Cost |               1 |
# | TotalEnvInteracts |        1.52e+03 |
# |              Time |        1.72e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |           Episode |             147 |
# |              Cost |               0 |
# | TotalEnvInteracts |        1.53e+03 |
# |              Time |        1.74e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |           Episode |             148 |
# |              Cost |               0 |
# | TotalEnvInteracts |        1.54e+03 |
# |              Time |        1.75e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |           Episode |             149 |
# |              Cost |               0 |
# | TotalEnvInteracts |        1.55e+03 |
# |              Time |        1.76e+03 |
# ---------------------------------------
# return data util  2412
# [4/70],loss train m: 0.0618, v: 0.0000, test m: 0.0948, v: 0.0000
# [9/70],loss train m: 0.0533, v: 0.0000, test m: 0.1004, v: 0.0000
# [14/70],loss train m: 0.0457, v: 0.0000, test m: 0.1047, v: 0.0000
# [19/70],loss train m: 0.0412, v: 0.0000, test m: 0.1069, v: 0.0000
# [24/70],loss train m: 0.0368, v: 0.0000, test m: 0.1072, v: 0.0000
# [29/70],loss train m: 0.0337, v: 0.0000, test m: 0.1112, v: 0.0000
# [34/70],loss train m: 0.0303, v: 0.0000, test m: 0.1126, v: 0.0000
# [LightGBM] [Info] Number of positive: 1136, number of negative: 1276
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000070 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 6375
# [LightGBM] [Info] Number of data points in the train set: 2412, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.470978 -> initscore=-0.116217
# [LightGBM] [Info] Start training from score -0.116217
# unsafe data accuracy: 100.00%, safe data accuracy: 100.00%

# %%
env = ContinuousRoundaboutEnv(render_mode='rgb_array')
env = RandomNormalNoisyObservation(env)
env.reset()

env, display = record_videos(env)

obs, _ = env.reset()
done = False
truncated = False
while not done and not truncated:
    action = mpc_controller.act(dynamic_model, obs.flatten())
    obs, reward, done, truncated, info = env.step(action)

display.stop()
del display
env.close()

show_videos()
# Out:
# [12/Dec/2023 22:55:46] INFO - Successfully started X with display ":1313".
# /Users/neha/anaconda3/envs/rl/lib/python3.10/site-packages/gymnasium/wrappers/record_video.py:94: UserWarning: WARN: Overwriting existing videos at /Users/neha/Documents/College/f23/CS378/videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Moviepy - Building video /Users/neha/Documents/College/f23/CS378/videos/rl-video-episode-0.mp4.
# Moviepy - Writing video /Users/neha/Documents/College/f23/CS378/videos/rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /Users/neha/Documents/College/f23/CS378/videos/rl-video-episode-0.mp4
# <video alt="videos/rl-video-episode-0.mp4" autoplay
#                       loop controls style="height: 400px;">
#                       <source src="data:video/mp4;base64,..." type="video/mp4" />
#                  </video>
